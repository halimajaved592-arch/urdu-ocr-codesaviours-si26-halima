# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset.csv')

print("Dataset shape:", df.shape)
display(df.head())
# Out:
# Dataset shape: (971, 3)
#                               sentence  word label
# 0  Aaj mera mood nahi hai for anything   Aaj   URD
# 1  Aaj mera mood nahi hai for anything  mera   URD
# 2  Aaj mera mood nahi hai for anything  mood   ENG
# 3  Aaj mera mood nahi hai for anything  nahi   URD
# 4  Aaj mera mood nahi hai for anything   hai   URD

# %%
print("Dataset shape:", df.shape)
display(df.head())
# Out:
# Dataset shape: (971, 3)
#                               sentence  word label
# 0  Aaj mera mood nahi hai for anything   Aaj   URD
# 1  Aaj mera mood nahi hai for anything  mera   URD
# 2  Aaj mera mood nahi hai for anything  mood   ENG
# 3  Aaj mera mood nahi hai for anything  nahi   URD
# 4  Aaj mera mood nahi hai for anything   hai   URD

# %%
print("Number of rows:", len(df))

print("\nLabel distribution:")
print(df["label"].value_counts())

print("\nUnique labels:")
print(df["label"].unique())
# Out:
# Number of rows: 971
#
# Label distribution:
# label
# URD    564
# ENG    358
# MIX     49
# Name: count, dtype: int64
#
# Unique labels:
# ['URD' 'ENG' 'MIX']

# %%
print("\nNumber of unique sentences:", df["sentence"].nunique())

print("\nSample sentences:")
for sentence in df["sentence"].unique()[:5]:
    print("-", sentence)
# Out:
# Number of unique sentences: 199
#
# Sample sentences:
# - Aaj mera mood nahi hai for anything
# - Yaar kal presentation hai still not ready
# - Tum online kyun nahi thay yesterday
# - Bhai assignment submit kar di I am relieved
# - Kal office bohot hectic tha honestly

# %%
print("All unique words currently labeled URD:")
print(df[df["label"] == "URD"]["word"].value_counts().head(50))

print("\nAll unique words currently labeled ENG:")
print(df[df["label"] == "ENG"]["word"].value_counts().head(50))
# Out:
# All unique words currently labeled URD:
# word
# Main       58
# hai        43
# bohot      41
# hoon       33
# Kal        31
# kar        29
# Tum        28
# raha       23
# tha        20
# Aaj        18
# Yeh        15
# ho         13
# Tumhara    10
# nahi        8
# kal         8
# ke          7
# abhi        7
# chuka       7
# mera        6
# ka          6
# mein        6
# Yaar        5
# dena        5
# se          5
# gaya        5
# karna       5
# Mera        4
# Bhai        4
# karunga     4
# do          4
# mujhe       3
# chal        3
# thi         3
# karni       3
# liye        3
# ghar        3
# Mujhe       3
# kab         2
# ja          2
# baad        2
# gayi        2
# pohanch     2
# bhej        2
# hain        2
# aya         2
# kyun        2
# lo          2
# jaldi       2
# jaunga      2
# sab         1
# Name: count, dtype: int64
#
# All unique words currently labeled ENG:
# word
# Please          20
# office          11
# assignment      10
# ...

# %%
# Show all 150 sentences
for i, sentence in enumerate(df["sentence"].unique(), 1):
    print(f"{i}. {sentence}")
# Out:
# 1. Aaj mera mood nahi hai for anything
# 2. Yaar kal presentation hai still not ready
# 3. Tum online kyun nahi thay yesterday
# 4. Bhai assignment submit kar di I am relieved
# 5. Kal office bohot hectic tha honestly
# 6. Main ghar pohanch gaya finally
# 7. Aaj weather bohot nice hai
# 8. Tum class miss kar gaye again
# 9. Mujhe coffee chahiye right now
# 10. Yeh movie bohot interesting thi
# 11. Kal meeting cancel ho gayi
# 12. Main abhi busy hoon call later
# 13. Tumhara idea really amazing hai
# 14. Yaar traffic bohot terrible tha
# 15. Lunch ke baad let's study
# 16. Mera phone battery low hai
# 17. Tum seriously bohot funny ho
# 18. Main project finish kar raha hoon
# 19. Aaj lecture bohot informative tha
# 20. Kal shopping ka plan hai
# 21. Tum meri help kar sakte ho
# 22. Main exam ke liye prepared hoon
# 23. Yeh task complete karna easy hai
# 24. Bhai game bohot addictive hai
# 25. Main library ja raha hoon now
# 26. Tumhara result finally aa gaya
# ...

# %%
sentences = df["sentence"].unique()

with open("sentences.txt", "w", encoding="utf-8") as f:
    for i, sentence in enumerate(sentences, 1):
        f.write(f"{i}. {sentence}\n")

print("Saved 150 sentences to sentences.txt")
# Out:
# Saved 150 sentences to sentences.txt

# %%
from google.colab import files
files.download("sentences.txt")

# %%
import pandas as pd

mix_data = [
    ("Main assignmentsubmitkarna bhool gayi", ["Main", "assignmentsubmitkarna", "bhool", "gayi"]),
    ("Please fileuploadkardo", ["Please", "fileuploadkardo"]),
    ("Kal meetingmein jana hai", ["Kal", "meetingmein", "jana", "hai"]),
    ("Main homeworkfinishkarna chahta hoon", ["Main", "homeworkfinishkarna", "chahta", "hoon"]),
    ("Tum presentationreadykarlo", ["Tum", "presentationreadykarlo"]),
    ("Main projectcompletekarunga", ["Main", "projectcompletekarunga"]),
    ("Please messageforwardkardo", ["Please", "messageforwardkardo"]),
    ("Kal assignmentsubmitkaro", ["Kal", "assignmentsubmitkaro"]),
    ("Main filedownloadkiya", ["Main", "filedownloadkiya"]),
    ("Tum meetingjoinkarlo", ["Tum", "meetingjoinkarlo"]),
    ("Main laptopchargekar raha hoon", ["Main", "laptopchargekar", "raha", "hoon"]),
    ("Please documentsharekardo", ["Please", "documentsharekardo"]),
    ("Main exampreparekar raha hoon", ["Main", "exampreparekar", "raha", "hoon"]),
    ("Tum homeworkcompletekarlo", ["Tum", "homeworkcompletekarlo"]),
    ("Main classattendkarunga", ["Main", "classattendkarunga"]),
    ("Kal projectsubmitkarna hai", ["Kal", "projectsubmitkarna", "hai"]),
    ("Please emailforwardkardo", ["Please", "emailforwardkardo"]),
    ("Main photoUploadkar raha hoon", ["Main", "photoUploadkar", "raha", "hoon"]),
    ("Tum fileattachkardo", ["Tum", "fileattachkardo"]),
    ("Main reportpreparekarunga", ["Main", "reportpreparekarunga"]),
    ("Please taskcompletekardo", ["Please", "taskcompletekardo"]),
    ("Kal lectureattendkarna hai", ["Kal", "lectureattendkarna", "hai"]),
    ("Main notesdownloadkiye", ["Main", "notesdownloadkiye"]),
    ("Tum assignmentcheckkaro", ["Tum", "assignmentcheckkaro"]),
    ("Main presentationfinishkarunga", ["Main", "presentationfinishkarunga"]),
    ("Please linksharekardo", ["Please", "linksharekardo"]),
    ("Main projectstartkar raha hoon", ["Main", "projectstartkar", "raha", "hoon"]),
    ("Tum documentuploadkaro", ["Tum", "documentuploadkaro"]),
    ("Main meetingattendkarunga", ["Main", "meetingattendkarunga"]),
    ("Kal homeworksubmitkarna hai", ["Kal", "homeworksubmitkarna", "hai"]),
    ("Please filecheckkardo", ["Please", "filecheckkardo"]),
    ("Main assignmentcompletekar chuka hoon", ["Main", "assignmentcompletekar", "chuka", "hoon"]),
    ("Tum projectfinishkaro", ["Tum", "projectfinishkaro"]),
    ("Main applicationdownloadki", ["Main", "applicationdownloadki"]),
    ("Please photoattachkardo", ["Please", "photoattachkardo"]),
    ("Kal classjoinkarna hai", ["Kal", "classjoinkarna", "hai"]),
    ("Main reportsubmitkar chuka hoon", ["Main", "reportsubmitkar", "chuka", "hoon"]),
    ("Tum presentationcheckkaro", ["Tum", "presentationcheckkaro"]),
    ("Please assignmentuploadkardo", ["Please", "assignmentuploadkardo"]),
    ("Main taskfinishkarunga", ["Main", "taskfinishkarunga"]),
    ("Kal meetingcancelkardo", ["Kal", "meetingcancelkardo"]),
    ("Tum filedownloadkaro", ["Tum", "filedownloadkaro"]),
    ("Main projectupdatekarunga", ["Main", "projectupdatekarunga"]),
    ("Please documentcheckkardo", ["Please", "documentcheckkardo"]),
    ("Kal exampreparekarna hai", ["Kal", "exampreparekarna", "hai"]),
    ("Main lecturefinishkar chuka hoon", ["Main", "lecturefinishkar", "chuka", "hoon"]),
    ("Tum messageforwardkardo", ["Tum", "messageforwardkardo"]),
    ("Please reportuploadkardo", ["Please", "reportuploadkardo"]),
    ("Main assignmentcheckkar raha hoon", ["Main", "assignmentcheckkar", "raha", "hoon"]),
]

urdu_words = {
    "Main", "Kal", "bhool", "gaya", "jana", "hai",
    "chahta", "hoon", "raha", "Tum", "karunga",
    "karna", "karlo", "karo", "kiya", "kiye",
    "chuka", "ki"
}

english_words = {
    "Please"
}

new_rows = []

for sentence, words in mix_data:
    for word in words:
        if word in english_words:
            label = "ENG"
        elif word in urdu_words:
            label = "URD"
        else:
            label = "MIX"

        new_rows.append({
            "sentence": sentence,
            "word": word,
            "label": label
        })

mix_df = pd.DataFrame(new_rows)

print("New rows:", len(mix_df))
print("New MIX examples:", (mix_df["label"] == "MIX").sum())

print("\nLabel distribution:")
print(mix_df["label"].value_counts())

display(mix_df.head(20))
# Out:
# New rows: 125
# New MIX examples: 50
#
# Label distribution:
# label
# URD    64
# MIX    50
# ENG    11
# Name: count, dtype: int64
#                                  sentence                    word label
# 0   Main assignmentsubmitkarna bhool gayi                    Main   URD
# 1   Main assignmentsubmitkarna bhool gayi   assignmentsubmitkarna   MIX
# 2   Main assignmentsubmitkarna bhool gayi                   bhool   URD
# 3   Main assignmentsubmitkarna bhool gayi                    gayi   MIX
# 4                  Please fileuploadkardo                  Please   ENG
# 5                  Please fileuploadkardo         fileuploadkardo   MIX
# 6                Kal meetingmein jana hai                     Kal   URD
# 7                Kal meetingmein jana hai             meetingmein   MIX
# 8                Kal meetingmein jana hai                    jana   URD
# 9                Kal meetingmein jana hai                     hai   URD
# ...

# %%
urdu_words.update({
    "gayi",
    "aaunga",
    "aaya",
    "aayi",
    "rahi",
    "kar",
    "karke",
    "se",
    "mein",
    "ke",
    "ka",
    "ki",
    "ko",
    "par",
    "ho",
    "hain",
    "tha",
    "thi",
    "the",
    "nahi",
    "abhi",
    "mujhe",
    "mera",
    "tumhara",
    "bohot"
})

print("Updated Urdu words:", len(urdu_words))
# Out:
# Updated Urdu words: 42

# %%
new_rows = []

for sentence, words in mix_data:
    for word in words:
        if word in english_words:
            label = "ENG"
        elif word in urdu_words:
            label = "URD"
        else:
            label = "MIX"

        new_rows.append({
            "sentence": sentence,
            "word": word,
            "label": label
        })

mix_df = pd.DataFrame(new_rows)

print("New rows:", len(mix_df))
print("New MIX examples:", (mix_df["label"] == "MIX").sum())
print("\nLabel distribution:")
print(mix_df["label"].value_counts())

display(mix_df.head(20))
# Out:
# New rows: 125
# New MIX examples: 49
#
# Label distribution:
# label
# URD    65
# MIX    49
# ENG    11
# Name: count, dtype: int64
#                                  sentence                    word label
# 0   Main assignmentsubmitkarna bhool gayi                    Main   URD
# 1   Main assignmentsubmitkarna bhool gayi   assignmentsubmitkarna   MIX
# 2   Main assignmentsubmitkarna bhool gayi                   bhool   URD
# 3   Main assignmentsubmitkarna bhool gayi                    gayi   URD
# 4                  Please fileuploadkardo                  Please   ENG
# 5                  Please fileuploadkardo         fileuploadkardo   MIX
# 6                Kal meetingmein jana hai                     Kal   URD
# 7                Kal meetingmein jana hai             meetingmein   MIX
# 8                Kal meetingmein jana hai                    jana   URD
# 9                Kal meetingmein jana hai                     hai   URD
# ...

# %%
# Combine original dataset with new MIX examples
final_df = pd.concat([df, mix_df], ignore_index=True)

# Remove any exact duplicate rows
final_df = final_df.drop_duplicates().reset_index(drop=True)

print("Final dataset shape:", final_df.shape)

print("\nNumber of unique sentences:", final_df["sentence"].nunique())

print("\nFinal label distribution:")
print(final_df["label"].value_counts())

display(final_df.head(20))
# Out:
# Final dataset shape: (971, 3)
#
# Number of unique sentences: 199
#
# Final label distribution:
# label
# URD    564
# ENG    358
# MIX     49
# Name: count, dtype: int64
#                                      sentence          word label
# 0         Aaj mera mood nahi hai for anything           Aaj   URD
# 1         Aaj mera mood nahi hai for anything          mera   URD
# 2         Aaj mera mood nahi hai for anything          mood   ENG
# 3         Aaj mera mood nahi hai for anything          nahi   URD
# 4         Aaj mera mood nahi hai for anything           hai   URD
# 5         Aaj mera mood nahi hai for anything           for   ENG
# 6         Aaj mera mood nahi hai for anything      anything   ENG
# 7   Yaar kal presentation hai still not ready          Yaar   URD
# 8   Yaar kal presentation hai still not ready           kal   URD
# 9   Yaar kal presentation hai still not ready  presentation   ENG
# 10  Yaar kal presentation hai still not ready           hai   URD
# ...

# %%
final_df.to_csv(
    "/content/drive/MyDrive/Colab Notebooks/dataset.csv",
    index=False,
    encoding="utf-8"
)

print("✅ Final dataset saved successfully!")
# Out:
# ✅ Final dataset saved successfully!

# %%
check_df = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/dataset.csv"
)

print("Rows:", len(check_df))
print("Sentences:", check_df["sentence"].nunique())
print("\nLabels:")
print(check_df["label"].value_counts())
# Out:
# Rows: 971
# Sentences: 199
#
# Labels:
# label
# URD    564
# ENG    358
# MIX     49
# Name: count, dtype: int64

# %%
label2id = {
    "URD": 0,
    "ENG": 1,
    "MIX": 2
}

id2label = {
    0: "URD",
    1: "ENG",
    2: "MIX"
}

print("Label mapping:", label2id)
# Out:
# Label mapping: {'URD': 0, 'ENG': 1, 'MIX': 2}

# %%
sentences = (
    final_df.groupby("sentence")
    .apply(lambda x: {
        "words": x["word"].tolist(),
        "labels": x["label"].tolist()
    })
    .tolist()
)

print("Total sentences:", len(sentences))

print("\nFirst sentence:")
print(sentences[0])
# Out:
# Total sentences: 199
#
# First sentence:
# {'words': ['Aaj', 'bohot', 'productive', 'day', 'tha'], 'labels': ['URD', 'URD', 'ENG', 'ENG', 'URD']}
# /tmp/ipykernel_743/4101409515.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: {

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(
    sentences,
    test_size=0.2,
    random_state=42
)

print("Training sentences:", len(train_data))
print("Testing sentences:", len(test_data))
# Out:
# Training sentences: 159
# Testing sentences: 40

# %%
# !pip install -q transformers datasets seqeval accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import torch

print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("GPU not detected.")
# Out:
# GPU available: True
# GPU: Tesla T4

# %%
import pandas as pd

df = pd.read_csv(
    "/content/drive/MyDrive/Colab Notebooks/dataset.csv"
)

print("Rows:", len(df))
print("Sentences:", df["sentence"].nunique())
print("\nLabels:")
print(df["label"].value_counts())
# Out:
# Rows: 971
# Sentences: 199
#
# Labels:
# label
# URD    564
# ENG    358
# MIX     49
# Name: count, dtype: int64

# %%
label2id = {
    "URD": 0,
    "ENG": 1,
    "MIX": 2
}

id2label = {
    0: "URD",
    1: "ENG",
    2: "MIX"
}

# %%
sentences = (
    df.groupby("sentence")
    .apply(
        lambda x: {
            "words": x["word"].tolist(),
            "labels": x["label"].tolist()
        }
    )
    .tolist()
)

print("Total sentences:", len(sentences))
# Out:
# Total sentences: 199
# /tmp/ipykernel_743/3032662953.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(
    sentences,
    test_size=0.2,
    random_state=42
)

print("Training sentences:", len(train_data))
print("Testing sentences:", len(test_data))
# Out:
# Training sentences: 159
# Testing sentences: 40

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification

model_name = "xlm-roberta-base"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForTokenClassification.from_pretrained(
    model_name,
    num_labels=3,
    id2label=id2label,
    label2id=label2id
)

print("✅ XLM-RoBERTa loaded successfully!")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.12GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# [transformers] XLMRobertaForTokenClassification LOAD REPORT from: xlm-roberta-base
# Key                         | Status     |
# ----------------------------+------------+-
# lm_head.bias                | UNEXPECTED |
# roberta.pooler.dense.weight | UNEXPECTED |
# lm_head.dense.bias          | UNEXPECTED |
# lm_head.layer_norm.weight   | UNEXPECTED |
# ...

# %%
def tokenize_and_align_labels(examples):
    tokenized = tokenizer(
        examples["words"],
        truncation=True,
        is_split_into_words=True
    )

    labels = []

    for i, label_list in enumerate(examples["labels"]):
        word_ids = tokenized.word_ids(batch_index=i)

        label_ids = []
        previous_word_id = None

        for word_id in word_ids:

            if word_id is None:
                label_ids.append(-100)

            elif word_id != previous_word_id:
                label_ids.append(
                    label2id[label_list[word_id]]
                )

            else:
                label_ids.append(-100)

            previous_word_id = word_id

        labels.append(label_ids)

    tokenized["labels"] = labels

    return tokenized

print("✅ Tokenization function ready!")
# Out:
# ✅ Tokenization function ready!

# %%
from datasets import Dataset

def to_hf_dataset(data):
    return Dataset.from_dict({
        "words": [d["words"] for d in data],
        "labels": [d["labels"] for d in data]
    })

train_ds = to_hf_dataset(train_data)
test_ds = to_hf_dataset(test_data)

print("Training dataset:", train_ds)
print("Testing dataset:", test_ds)
# Out:
# Training dataset: Dataset({
#     features: ['words', 'labels'],
#     num_rows: 159
# })
# Testing dataset: Dataset({
#     features: ['words', 'labels'],
#     num_rows: 40
# })

# %%
train_ds = train_ds.map(
    tokenize_and_align_labels,
    batched=True
)

test_ds = test_ds.map(
    tokenize_and_align_labels,
    batched=True
)

print("✅ Tokenization completed!")
print("Training rows:", len(train_ds))
print("Testing rows:", len(test_ds))
# Out:
# ...
# Map:   0%|          | 0/40 [00:00<?, ? examples/s]
# ✅ Tokenization completed!
# Training rows: 159
# Testing rows: 40

# %%
print(train_ds[0])
# Out:
# {'words': ['Yaar', 'traffic', 'bohot', 'terrible', 'tha'], 'labels': [-100, 0, 1, 0, -100, 1, 0, -100], 'input_ids': [0, 169092, 83629, 337, 21620, 94176, 3319, 2], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}

# %%
from transformers import (
    TrainingArguments,
    Trainer,
    DataCollatorForTokenClassification
)

training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_steps=10,
    load_best_model_at_end=True,
    report_to="none",
    fp16=True
)

print("✅ Training arguments ready!")
# Out:
# ✅ Training arguments ready!

# %%
data_collator = DataCollatorForTokenClassification(
    tokenizer=tokenizer
)

print("✅ Data collator ready!")
# Out:
# ✅ Data collator ready!

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    data_collator=data_collator
)

print("✅ Trainer ready!")
# Out:
# ✅ Trainer ready!

# %%
train_result = trainer.train()

print("✅ Training completed!")
# Out:
#     <div>
#
#       <progress value='50' max='50' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [50/50 11:44, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.938219</td>
#       <td>0.516458</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.376921</td>
#       <td>0.181423</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.185691</td>
#       <td>0.100387</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.104780</td>
#       <td>0.073850</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.086298</td>
#       <td>0.062118</td>
#     </tr>
#   </tbody>
# </table><p>
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Training completed!

# %%
save_path = "/content/drive/MyDrive/Colab Notebooks/week7_model"

trainer.save_model(save_path)
tokenizer.save_pretrained(save_path)

print("✅ Model saved successfully!")
print("Saved to:", save_path)
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# ✅ Model saved successfully!
# Saved to: /content/drive/MyDrive/Colab Notebooks/week7_model

# %%
eval_results = trainer.evaluate()

print("✅ Evaluation completed!")
print(eval_results)
# Out:
#     <div>
#
#       <progress value='3' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3/3 00:00]
#     </div>
# <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Epoch</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.086298</td>
#       <td>0.062118</td>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Evaluation completed!
# {'eval_loss': 0.0621175579726696}

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# Get predictions
predictions = trainer.predict(test_ds)

logits = predictions.predictions
true_labels = predictions.label_ids

# Convert logits to predicted label IDs
pred_labels = np.argmax(logits, axis=-1)

# Remove ignored tokens (-100)
y_true = []
y_pred = []

for true_seq, pred_seq in zip(true_labels, pred_labels):
    for true_label, pred_label in zip(true_seq, pred_seq):
        if true_label != -100:
            y_true.append(true_label)
            y_pred.append(pred_label)

# Metrics
accuracy = accuracy_score(y_true, y_pred)

precision, recall, f1, _ = precision_recall_fscore_support(
    y_true,
    y_pred,
    average="weighted",
    zero_division=0
)

print("================================")
print("WEEK 7 EVALUATION RESULTS")
print("================================")
print(f"Accuracy :  {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"Precision:  {precision:.4f} ({precision*100:.2f}%)")
print(f"Recall   :  {recall:.4f} ({recall*100:.2f}%)")
print(f"F1 Score :  {f1:.4f} ({f1*100:.2f}%)")
# Out:
# ...
# WEEK 7 EVALUATION RESULTS
# ...
# Accuracy :  0.9643 (96.43%)
# Precision:  0.9664 (96.64%)
# Recall   :  0.9643 (96.43%)
# F1 Score :  0.9612 (96.12%)

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_true,
    y_pred,
    target_names=[
        id2label[0],
        id2label[1],
        id2label[2]
    ],
    zero_division=0
))
# Out:
#               precision    recall  f1-score   support
#
#          URD       0.99      0.99      0.99       118
#          ENG       0.92      0.99      0.95        67
#          MIX       1.00      0.55      0.71        11
#
#     accuracy                           0.96       196
#    macro avg       0.97      0.84      0.88       196
# weighted avg       0.97      0.96      0.96       196

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
plt.imshow(cm)
plt.title("Week 7 Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks([0, 1, 2], ["URD", "ENG", "MIX"])
plt.yticks([0, 1, 2], ["URD", "ENG", "MIX"])

for i in range(3):
    for j in range(3):
        plt.text(j, i, cm[i, j], ha="center", va="center")

plt.colorbar()
plt.show()

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[117   1   0]
#  [  1  66   0]
#  [  0   5   6]]

# %%
import json
import os

results = {
    "accuracy": 0.9643,
    "precision": 0.9664,
    "recall": 0.9643,
    "f1_score": 0.9612,
    "validation_loss": 0.0621175579726696,
    "epochs": 5,
    "per_class": {
        "URD": {
            "precision": 0.99,
            "recall": 0.99,
            "f1": 0.99,
            "support": 118
        },
        "ENG": {
            "precision": 0.92,
            "recall": 0.99,
            "f1": 0.95,
            "support": 67
        },
        "MIX": {
            "precision": 1.00,
            "recall": 0.55,
            "f1": 0.71,
            "support": 11
        }
    }
}

results_path = "/content/drive/MyDrive/Colab Notebooks/week7_results.json"

with open(results_path, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=4)

print("✅ Evaluation results saved!")
print(results_path)
# Out:
# ✅ Evaluation results saved!
# /content/drive/MyDrive/Colab Notebooks/week7_results.json

# %%
import os

save_path = "/content/drive/MyDrive/Colab Notebooks/week7_model"

print("Model folder exists:", os.path.exists(save_path))

if os.path.exists(save_path):
    print("\nSaved files:")
    for file in os.listdir(save_path):
        print("✅", file)
# Out:
# Model folder exists: True
#
# Saved files:
# ✅ config.json
# ✅ model.safetensors
# ✅ tokenizer_config.json
# ✅ tokenizer.json
# ✅ training_args.bin
