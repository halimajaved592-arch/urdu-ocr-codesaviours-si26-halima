# %%
data = [
    {
        "sentence": "Aaj mera mood nahi hai for anything",
        "words": ["Aaj","mera","mood","nahi","hai","for","anything"],
        "labels": ["URD","URD","ENG","URD","URD","ENG","ENG"]
    },
    {
        "sentence": "Yaar kal presentation hai still not ready",
        "words": ["Yaar","kal","presentation","hai","still","not","ready"],
        "labels": ["URD","URD","ENG","URD","ENG","ENG","ENG"]
    },
    {
        "sentence": "Tum online kyun nahi thay yesterday",
        "words": ["Tum","online","kyun","nahi","thay","yesterday"],
        "labels": ["URD","ENG","URD","URD","URD","ENG"]
    },
    {
        "sentence": "Bhai assignment submit kar di I am relieved",
        "words": ["Bhai","assignment","submit","kar","di","I","am","relieved"],
        "labels": ["URD","ENG","ENG","URD","URD","ENG","ENG","ENG"]
    },
    {
        "sentence": "Kal office bohot hectic tha honestly",
        "words": ["Kal","office","bohot","hectic","tha","honestly"],
        "labels": ["URD","ENG","URD","ENG","URD","ENG"]
    },
    {
        "sentence": "Main ghar pohanch gaya finally",
        "words": ["Main","ghar","pohanch","gaya","finally"],
        "labels": ["URD","URD","URD","URD","ENG"]
    },
    {
        "sentence": "Aaj weather bohot nice hai",
        "words": ["Aaj","weather","bohot","nice","hai"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Tum class miss kar gaye again",
        "words": ["Tum","class","miss","kar","gaye","again"],
        "labels": ["URD","ENG","ENG","URD","URD","ENG"]
    },
    {
        "sentence": "Mujhe coffee chahiye right now",
        "words": ["Mujhe","coffee","chahiye","right","now"],
        "labels": ["URD","ENG","URD","ENG","ENG"]
    },
    {
        "sentence": "Yeh movie bohot interesting thi",
        "words": ["Yeh","movie","bohot","interesting","thi"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Kal meeting cancel ho gayi",
        "words": ["Kal","meeting","cancel","ho","gayi"],
        "labels": ["URD","ENG","ENG","URD","URD"]
    },
    {
        "sentence": "Main abhi busy hoon call later",
        "words": ["Main","abhi","busy","hoon","call","later"],
        "labels": ["URD","URD","ENG","URD","ENG","ENG"]
    },
    {
        "sentence": "Tumhara idea really amazing hai",
        "words": ["Tumhara","idea","really","amazing","hai"],
        "labels": ["URD","ENG","ENG","ENG","URD"]
    },
    {
        "sentence": "Yaar traffic bohot terrible tha",
        "words": ["Yaar","traffic","bohot","terrible","tha"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Lunch ke baad let's study",
        "words": ["Lunch","ke","baad","let's","study"],
        "labels": ["ENG","URD","URD","ENG","ENG"]
    },
    {
        "sentence": "Mera phone battery low hai",
        "words": ["Mera","phone","battery","low","hai"],
        "labels": ["URD","ENG","ENG","ENG","URD"]
    },
    {
        "sentence": "Tum seriously bohot funny ho",
        "words": ["Tum","seriously","bohot","funny","ho"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Main project finish kar raha hoon",
        "words": ["Main","project","finish","kar","raha","hoon"],
        "labels": ["URD","ENG","ENG","URD","URD","URD"]
    },
    {
        "sentence": "Aaj lecture bohot informative tha",
        "words": ["Aaj","lecture","bohot","informative","tha"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Kal shopping ka plan hai",
        "words": ["Kal","shopping","ka","plan","hai"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Tum meri help kar sakte ho",
        "words": ["Tum","meri","help","kar","sakte","ho"],
        "labels": ["URD","URD","ENG","URD","URD","URD"]
    },
    {
        "sentence": "Main exam ke liye prepared hoon",
        "words": ["Main","exam","ke","liye","prepared","hoon"],
        "labels": ["URD","ENG","URD","URD","ENG","URD"]
    },
    {
        "sentence": "Yeh task complete karna easy hai",
        "words": ["Yeh","task","complete","karna","easy","hai"],
        "labels": ["URD","ENG","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Bhai game bohot addictive hai",
        "words": ["Bhai","game","bohot","addictive","hai"],
        "labels": ["URD","ENG","URD","ENG","URD"]
    },
    {
        "sentence": "Main library ja raha hoon now",
        "words": ["Main","library","ja","raha","hoon","now"],
        "labels": ["URD","ENG","URD","URD","URD","ENG"]
    },
    {
        "sentence": "Tumhara result finally aa gaya",
        "words": ["Tumhara","result","finally","aa","gaya"],
        "labels": ["URD","ENG","ENG","URD","URD"]
    },
    {
        "sentence": "Ab sab kuch under control hai",
        "words": ["Ab","sab","kuch","under","control","hai"],
        "labels": ["URD","URD","URD","ENG","ENG","URD"]
    },
    {
        "sentence": "Main bohot excited hoon today",
        "words": ["Main","bohot","excited","hoon","today"],
        "labels": ["URD","URD","ENG","URD","ENG"]
    },
    {
        "sentence": "Kal deadline hai don't forget",
        "words": ["Kal","deadline","hai","don't","forget"],
        "labels": ["URD","ENG","URD","ENG","ENG"]
    },
    {
        "sentence": "Yeh idea actually bohot useful hai",
        "words": ["Yeh","idea","actually","bohot","useful","hai"],
        "labels": ["URD","ENG","ENG","URD","ENG","URD"]
    },
    {
    "sentence": "Mujhe ye assignment complete karni hai today",
    "words": ["Mujhe","ye","assignment","complete","karni","hai","today"],
    "labels": ["URD","URD","ENG","ENG","URD","URD","ENG"]
},
{
    "sentence": "Bhai laptop charge nahi ho raha",
    "words": ["Bhai","laptop","charge","nahi","ho","raha"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal quiz hai be prepared",
    "words": ["Kal","quiz","hai","be","prepared"],
    "labels": ["URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Main office late pohancha because traffic",
    "words": ["Main","office","late","pohancha","because","traffic"],
    "labels": ["URD","ENG","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Aaj bohot productive day tha",
    "words": ["Aaj","bohot","productive","day","tha"],
    "labels": ["URD","URD","ENG","ENG","URD"]
},
{
    "sentence": "Tumhara message abhi receive hua",
    "words": ["Tumhara","message","abhi","receive","hua"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Please mujhe update bhej dena",
    "words": ["Please","mujhe","update","bhej","dena"],
    "labels": ["ENG","URD","ENG","URD","URD"]
},
{
    "sentence": "Aaj class bohot interesting thi",
    "words": ["Aaj","class","bohot","interesting","thi"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main market ja raha hoon later",
    "words": ["Main","market","ja","raha","hoon","later"],
    "labels": ["URD","ENG","URD","URD","URD","ENG"]
},
{
    "sentence": "Tum kal free ho for lunch",
    "words": ["Tum","kal","free","ho","for","lunch"],
    "labels": ["URD","URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Yeh project bohot challenging hai",
    "words": ["Yeh","project","bohot","challenging","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Mera internet bohot slow chal raha hai",
    "words": ["Mera","internet","bohot","slow","chal","raha","hai"],
    "labels": ["URD","ENG","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Tumhara idea really helpful tha",
    "words": ["Tumhara","idea","really","helpful","tha"],
    "labels": ["URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Kal meeting attend karna please",
    "words": ["Kal","meeting","attend","karna","please"],
    "labels": ["URD","ENG","ENG","URD","ENG"]
},
{
    "sentence": "Main bohot tired hoon today",
    "words": ["Main","bohot","tired","hoon","today"],
    "labels": ["URD","URD","ENG","URD","ENG"]
},
{
    "sentence": "Yaar coffee peene chalte hain",
    "words": ["Yaar","coffee","peene","chalte","hain"],
    "labels": ["URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Abhi lecture start hone wala hai",
    "words": ["Abhi","lecture","start","hone","wala","hai"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Main homework complete kar chuka hoon",
    "words": ["Main","homework","complete","kar","chuka","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Yeh phone bohot expensive hai",
    "words": ["Yeh","phone","bohot","expensive","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal movie dekhne ka plan hai",
    "words": ["Kal","movie","dekhne","ka","plan","hai"],
    "labels": ["URD","ENG","URD","URD","ENG","URD"]
},
{
    "sentence": "Tum assignment email kar do",
    "words": ["Tum","assignment","email","kar","do"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main room clean kar raha hoon",
    "words": ["Main","room","clean","kar","raha","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Please jaldi reply karna",
    "words": ["Please","jaldi","reply","karna"],
    "labels": ["ENG","URD","ENG","URD"]
},
{
    "sentence": "Aaj lunch bohot tasty tha",
    "words": ["Aaj","lunch","bohot","tasty","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum online kab aoge tonight",
    "words": ["Tum","online","kab","aoge","tonight"],
    "labels": ["URD","ENG","URD","URD","ENG"]
},
{
    "sentence": "Main library mein study kar raha hoon",
    "words": ["Main","library","mein","study","kar","raha","hoon"],
    "labels": ["URD","ENG","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Yeh game bohot addictive nikla",
    "words": ["Yeh","game","bohot","addictive","nikla"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal office work zyada tha",
    "words": ["Kal","office","work","zyada","tha"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main abhi dinner bana raha hoon",
    "words": ["Main","abhi","dinner","bana","raha","hoon"],
    "labels": ["URD","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Tumhara presentation bohot impressive tha",
    "words": ["Tumhara","presentation","bohot","impressive","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
    {
    "sentence": "Aaj mera internet bohot slow hai",
    "words": ["Aaj","mera","internet","bohot","slow","hai"],
    "labels": ["URD","URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal interview hai wish me luck",
    "words": ["Kal","interview","hai","wish","me","luck"],
    "labels": ["URD","ENG","URD","ENG","ENG","ENG"]
},
{
    "sentence": "Main abhi office mein busy hoon",
    "words": ["Main","abhi","office","mein","busy","hoon"],
    "labels": ["URD","URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Yeh idea bohot creative hai",
    "words": ["Yeh","idea","bohot","creative","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum assignment upload kar do",
    "words": ["Tum","assignment","upload","kar","do"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj weather perfect hai for picnic",
    "words": ["Aaj","weather","perfect","hai","for","picnic"],
    "labels": ["URD","ENG","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Mera phone hang ho gaya",
    "words": ["Mera","phone","hang","ho","gaya"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main homework complete kar raha hoon",
    "words": ["Main","homework","complete","kar","raha","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal shopping ke liye chalna",
    "words": ["Kal","shopping","ke","liye","chalna"],
    "labels": ["URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Tum bohot talented ho honestly",
    "words": ["Tum","bohot","talented","ho","honestly"],
    "labels": ["URD","URD","ENG","URD","ENG"]
},
{
    "sentence": "Yaar project ka deadline close hai",
    "words": ["Yaar","project","ka","deadline","close","hai"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Main lecture attend nahi kar saka",
    "words": ["Main","lecture","attend","nahi","kar","saka"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Aaj dinner bahar karte hain",
    "words": ["Aaj","dinner","bahar","karte","hain"],
    "labels": ["URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Tumhara laptop bohot fast hai",
    "words": ["Tumhara","laptop","bohot","fast","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal sir ne assignment explain ki",
    "words": ["Kal","sir","ne","assignment","explain","ki"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD"]
},
{
    "sentence": "Main market se groceries le aya",
    "words": ["Main","market","se","groceries","le","aya"],
    "labels": ["URD","ENG","URD","ENG","URD","URD"]
},
{
    "sentence": "Please document upload kar dena",
    "words": ["Please","document","upload","kar","dena"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj meeting bohot productive thi",
    "words": ["Aaj","meeting","bohot","productive","thi"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum free ho let's go",
    "words": ["Tum","free","ho","let's","go"],
    "labels": ["URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Main movie download kar raha hoon",
    "words": ["Main","movie","download","kar","raha","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Yeh coffee bohot amazing hai",
    "words": ["Yeh","coffee","bohot","amazing","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal exam ke baad celebrate karenge",
    "words": ["Kal","exam","ke","baad","celebrate","karenge"],
    "labels": ["URD","ENG","URD","URD","ENG","URD"]
},
{
    "sentence": "Main bohot excited hoon for tomorrow",
    "words": ["Main","bohot","excited","hoon","for","tomorrow"],
    "labels": ["URD","URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Tumhara result finally aa gaya",
    "words": ["Tumhara","result","finally","aa","gaya"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Please camera on kar lo",
    "words": ["Please","camera","on","kar","lo"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main kal office nahi aaunga",
    "words": ["Main","kal","office","nahi","aaunga"],
    "labels": ["URD","URD","ENG","URD","URD"]
},
{
    "sentence": "Yeh lecture samajhna easy tha",
    "words": ["Yeh","lecture","samajhna","easy","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Bhai game update kab ayegi",
    "words": ["Bhai","game","update","kab","ayegi"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main room clean kar chuka hoon",
    "words": ["Main","room","clean","kar","chuka","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal bohot important meeting hai",
    "words": ["Kal","bohot","important","meeting","hai"],
    "labels": ["URD","URD","ENG","ENG","URD"]
},
    {
    "sentence": "Main kal library jaunga after class",
    "words": ["Main","kal","library","jaunga","after","class"],
    "labels": ["URD","URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Yaar mera charger mil nahi raha",
    "words": ["Yaar","mera","charger","mil","nahi","raha"],
    "labels": ["URD","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Tum assignment finish kar chuke ho",
    "words": ["Tum","assignment","finish","kar","chuke","ho"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Aaj lecture really informative tha",
    "words": ["Aaj","lecture","really","informative","tha"],
    "labels": ["URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Main office se ghar late aya",
    "words": ["Main","office","se","ghar","late","aya"],
    "labels": ["URD","ENG","URD","URD","ENG","URD"]
},
{
    "sentence": "Kal shopping karni hai with friends",
    "words": ["Kal","shopping","karni","hai","with","friends"],
    "labels": ["URD","ENG","URD","URD","ENG","ENG"]
},
{
    "sentence": "Tum online the but reply nahi diya",
    "words": ["Tum","online","the","but","reply","nahi","diya"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Please file upload kar dena today",
    "words": ["Please","file","upload","kar","dena","today"],
    "labels": ["ENG","ENG","ENG","URD","URD","ENG"]
},
{
    "sentence": "Yeh phone bohot smooth chal raha hai",
    "words": ["Yeh","phone","bohot","smooth","chal","raha","hai"],
    "labels": ["URD","ENG","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Main project complete kar ke soya",
    "words": ["Main","project","complete","kar","ke","soya"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal interview ka result ayega",
    "words": ["Kal","interview","ka","result","ayega"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum bohot confident lag rahe ho",
    "words": ["Tum","bohot","confident","lag","rahe","ho"],
    "labels": ["URD","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Mujhe meeting join karni hai",
    "words": ["Mujhe","meeting","join","karni","hai"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj dinner bohot delicious tha",
    "words": ["Aaj","dinner","bohot","delicious","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main notes revise kar raha hoon",
    "words": ["Main","notes","revise","kar","raha","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal office mein bohot work tha",
    "words": ["Kal","office","mein","bohot","work","tha"],
    "labels": ["URD","ENG","URD","URD","ENG","URD"]
},
{
    "sentence": "Please laptop restart kar lo",
    "words": ["Please","laptop","restart","kar","lo"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Yeh task complete karna simple hai",
    "words": ["Yeh","task","complete","karna","simple","hai"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main abhi campus mein hoon",
    "words": ["Main","abhi","campus","mein","hoon"],
    "labels": ["URD","URD","ENG","URD","URD"]
},
{
    "sentence": "Tumhara idea actually kaafi useful hai",
    "words": ["Tumhara","idea","actually","kaafi","useful","hai"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal seminar attend karna zaroor",
    "words": ["Kal","seminar","attend","karna","zaroor"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main room decorate kar raha hoon",
    "words": ["Main","room","decorate","kar","raha","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Aaj bohot relaxing day tha",
    "words": ["Aaj","bohot","relaxing","day","tha"],
    "labels": ["URD","URD","ENG","ENG","URD"]
},
{
    "sentence": "Tum mujhe update bhej dena",
    "words": ["Tum","mujhe","update","bhej","dena"],
    "labels": ["URD","URD","ENG","URD","URD"]
},
{
    "sentence": "Main assignment submit kar chuka hoon",
    "words": ["Main","assignment","submit","kar","chuka","hoon"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal weather cloudy tha but nice",
    "words": ["Kal","weather","cloudy","tha","but","nice"],
    "labels": ["URD","ENG","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Yeh app bohot useful nikli",
    "words": ["Yeh","app","bohot","useful","nikli"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main kal train se travel karunga",
    "words": ["Main","kal","train","se","travel","karunga"],
    "labels": ["URD","URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum ready ho let's leave",
    "words": ["Tum","ready","ho","let's","leave"],
    "labels": ["URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Aaj mera schedule bohot busy hai",
    "words": ["Aaj","mera","schedule","bohot","busy","hai"],
    "labels": ["URD","URD","ENG","URD","ENG","URD"]
},
    {
    "sentence": "Kal mera schedule bohot tight hai",
    "words": ["Kal","mera","schedule","bohot","tight","hai"],
    "labels": ["URD","URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main office se jaldi nikal gaya",
    "words": ["Main","office","se","jaldi","nikal","gaya"],
    "labels": ["URD","ENG","URD","URD","URD","URD"]
},
{
    "sentence": "Please assignment upload kar do",
    "words": ["Please","assignment","upload","kar","do"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Tumhara presentation really impressive tha",
    "words": ["Tumhara","presentation","really","impressive","tha"],
    "labels": ["URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Aaj bohot productive meeting hui",
    "words": ["Aaj","bohot","productive","meeting","hui"],
    "labels": ["URD","URD","ENG","ENG","URD"]
},
{
    "sentence": "Main library mein assignment likh raha hoon",
    "words": ["Main","library","mein","assignment","likh","raha","hoon"],
    "labels": ["URD","ENG","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Kal exam ke liye best of luck",
    "words": ["Kal","exam","ke","liye","best","of","luck"],
    "labels": ["URD","ENG","URD","URD","ENG","ENG","ENG"]
},
{
    "sentence": "Yeh laptop bohot fast chal raha hai",
    "words": ["Yeh","laptop","bohot","fast","chal","raha","hai"],
    "labels": ["URD","ENG","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Main abhi online class attend kar raha hoon",
    "words": ["Main","abhi","online","class","attend","kar","raha","hoon"],
    "labels": ["URD","URD","ENG","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Tum free ho after dinner",
    "words": ["Tum","free","ho","after","dinner"],
    "labels": ["URD","ENG","URD","ENG","ENG"]
},
{
    "sentence": "Kal office mein new project start hoga",
    "words": ["Kal","office","mein","new","project","start","hoga"],
    "labels": ["URD","ENG","URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Mera internet connection ab theek hai",
    "words": ["Mera","internet","connection","ab","theek","hai"],
    "labels": ["URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Please mujhe document email kar dena",
    "words": ["Please","mujhe","document","email","kar","dena"],
    "labels": ["ENG","URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj lunch bohot delicious tha",
    "words": ["Aaj","lunch","bohot","delicious","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main kal shopping karne jaunga",
    "words": ["Main","kal","shopping","karne","jaunga"],
    "labels": ["URD","URD","ENG","URD","URD"]
},
{
    "sentence": "Tumhara phone silent par tha",
    "words": ["Tumhara","phone","silent","par","tha"],
    "labels": ["URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Yeh movie dekhna totally worth it",
    "words": ["Yeh","movie","dekhna","totally","worth","it"],
    "labels": ["URD","ENG","URD","ENG","ENG","ENG"]
},
{
    "sentence": "Main project complete karke submit karunga",
    "words": ["Main","project","complete","karke","submit","karunga"],
    "labels": ["URD","ENG","ENG","URD","ENG","URD"]
},
{
    "sentence": "Kal weather bohot pleasant tha",
    "words": ["Kal","weather","bohot","pleasant","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum online kyun nahi aaye",
    "words": ["Tum","online","kyun","nahi","aaye"],
    "labels": ["URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Main office ka work finish kar chuka hoon",
    "words": ["Main","office","ka","work","finish","kar","chuka","hoon"],
    "labels": ["URD","ENG","URD","ENG","ENG","URD","URD","URD"]
},
{
    "sentence": "Aaj lecture ka topic bohot interesting tha",
    "words": ["Aaj","lecture","ka","topic","bohot","interesting","tha"],
    "labels": ["URD","ENG","URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Please camera off kar do",
    "words": ["Please","camera","off","kar","do"],
    "labels": ["ENG","ENG","ENG","URD","URD"]
},
{
    "sentence": "Main ghar pohanch ke call karunga",
    "words": ["Main","ghar","pohanch","ke","call","karunga"],
    "labels": ["URD","URD","URD","URD","ENG","URD"]
},
{
    "sentence": "Tumhara assignment almost complete hai",
    "words": ["Tumhara","assignment","almost","complete","hai"],
    "labels": ["URD","ENG","ENG","ENG","URD"]
},
{
    "sentence": "Kal seminar bohot informative tha",
    "words": ["Kal","seminar","bohot","informative","tha"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Main abhi breakfast kar raha hoon",
    "words": ["Main","abhi","breakfast","kar","raha","hoon"],
    "labels": ["URD","URD","ENG","URD","URD","URD"]
},
{
    "sentence": "Yeh application bohot useful hai",
    "words": ["Yeh","application","bohot","useful","hai"],
    "labels": ["URD","ENG","URD","ENG","URD"]
},
{
    "sentence": "Tum kal meeting join kar lena",
    "words": ["Tum","kal","meeting","join","kar","lena"],
    "labels": ["URD","URD","ENG","ENG","URD","URD"]
},
{
    "sentence": "Aaj mera kaam finally complete ho gaya",
    "words": ["Aaj","mera","kaam","finally","complete","ho","gaya"],
    "labels": ["URD","URD","URD","ENG","ENG","URD","URD"]
},
    {
    "sentence": "Main kal office se work from home karunga",
    "words": ["Main","kal","office","se","work","from","home","karunga"],
    "labels": ["URD","URD","ENG","URD","ENG","ENG","ENG","URD"]
}
]
import pandas as pd

rows = []

for entry in data:
    for word, label in zip(entry["words"], entry["labels"]):
        rows.append({
            "sentence": entry["sentence"],
            "word": word,
            "label": label
        })

df = pd.DataFrame(rows)

df.to_csv("dataset.csv", index=False, encoding="utf-8")

print(f"Dataset created: {len(df)} word entries")
print(f"Sentences: {df.sentence.nunique()}")
print(df.label.value_counts())
# Out:
# Dataset created: 851 word entries
# Sentences: 150
# label
# URD    502
# ENG    349
# Name: count, dtype: int64
