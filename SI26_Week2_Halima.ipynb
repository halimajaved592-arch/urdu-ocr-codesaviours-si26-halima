# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install opencv-python

# %%
import cv2
import os
import matplotlib.pyplot as plt

# %%
import os

print(os.listdir('/content/drive/MyDrive/Colab Notebooks'))
# Out:
# ['SI26-Week2-Halima.ipynb', 'Untitled0.ipynb', 'Untitled', 'SI26-Week1-halima.ipynb', 'week2_data']

# %%
print(os.listdir('/content/drive/MyDrive/Colab Notebooks/week2_data')[:10])
# Out:
# ['5.png', '52.png', '53.png', '34.png', '32.png', '24.png', '27.png', '25.png', '23.png', '30.png']

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/week2_data/5.png')

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(gray, cmap='gray')
plt.axis('off')
plt.show()

# %%
blur = cv2.GaussianBlur(gray, (5,5), 0)

plt.imshow(blur, cmap='gray')
plt.axis('off')
plt.show()

# %%
_, thresh = cv2.threshold(blur, 150, 255, cv2.THRESH_BINARY)

plt.imshow(thresh, cmap='gray')
plt.axis('off')
plt.show()

# %%
import os

input_folder = "/content/drive/MyDrive/Colab Notebooks/week2_data"
output_folder = "/content/drive/MyDrive/Colab Notebooks/data/processed"

os.makedirs(output_folder, exist_ok=True)

print("Processed folder created!")
# Out:
# Processed folder created!

# %%
import cv2
import os

for filename in os.listdir(input_folder):

    image_path = os.path.join(input_folder, filename)

    img = cv2.imread(image_path)

    if img is None:
        continue

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Remove noise
    blur = cv2.GaussianBlur(gray, (5,5), 0)

    # Convert to black & white
    _, thresh = cv2.threshold(blur, 150, 255, cv2.THRESH_BINARY)

    save_path = os.path.join(output_folder, filename)

    cv2.imwrite(save_path, thresh)

print("All images processed successfully!")
# Out:
# All images processed successfully!

# %%
print(os.listdir(output_folder)[:10])
# Out:
# ['5.png', '52.png', '53.png', '34.png', '32.png', '24.png', '27.png', '25.png', '23.png', '30.png']

# %%
import matplotlib.pyplot as plt

img = cv2.imread("/content/drive/MyDrive/Colab Notebooks/data/processed/5.png")

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
# !apt-get install tesseract-ocr -y
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# ...

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.listdir('/content/drive/MyDrive')[:20])
# Out:
# ['Copy of lab manual DS.docx', 'lab manual DS (1).docx', 'lab manual DS.docx', 'H.J Manual copy 2.0.odt', 'H.J Manual copy 2.0.gdoc', 'ASSIGNMENT of PSYCHOLOGY.pdf', 'ASSIGNMENT of PSYCHOLOGY.gdoc', 'Classroom', 'Photoroom_20250722_182554.png', 'BFS AND DFS (1).pptx', 'xampp.zip', 'Copy of 9.png', 'Copy of 1.jpg', 'Copy of 66.jpg', 'Copy of 4.png', 'Copy of 3.jpg', 'State Machine Diagram\nMsg\nsent process on whatsapp.gsheet', 'Colab Notebooks', 'ESD.xlsx', 'Copy of ESD.xlsx']

# %%
import os

for root, dirs, files in os.walk('/content/drive/MyDrive'):
    if 'week2_data' in dirs:
        print(os.path.join(root, 'week2_data'))
# Out:
# /content/drive/MyDrive/Colab Notebooks/week2_data

# %%
import os

for root, dirs, files in os.walk('/content/drive/MyDrive'):
    if 'processed' in dirs:
        print(os.path.join(root, 'processed'))
# Out:
# /content/drive/MyDrive/Colab Notebooks/data/processed

# %%
import os

print(os.listdir('/content/drive/MyDrive/Colab Notebooks/data/processed')[:10])
# Out:
# ['5.png', '52.png', '53.png', '34.png', '32.png', '24.png', '27.png', '25.png', '23.png', '30.png']

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/data/processed/5.png')

print(img is None)
# Out:
# False

# %%
print(os.listdir('/content/drive/MyDrive/Colab Notebooks/data/processed')[:20])
# Out:
# ['5.png', '52.png', '53.png', '34.png', '32.png', '24.png', '27.png', '25.png', '23.png', '30.png', '31.png', '35.png', '28.png', '14.png', '37.png', '4.png', '15.png', '1.png', '50.png', '47.png']

# %%
import matplotlib.pyplot as plt

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# !apt-get install tesseract-ocr -y
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# ...

# %%
import pytesseract

# %%
text = pytesseract.image_to_string(img)

print("OCR Output:")
print(text)
# Out:
# OCR Output:
# Ein SiS Pa LAS uty NE

# %%
import os
import cv2
import pytesseract

folder = "/content/drive/MyDrive/Colab Notebooks/data/processed"

for filename in os.listdir(folder)[:5]:
    path = os.path.join(folder, filename)

    image = cv2.imread(path)

    text = pytesseract.image_to_string(image)

    print("Image:", filename)
    print("OCR Output:")
    print(text)
    print("-" * 40)
# Out:
# Image: 5.png
# OCR Output:
# Ein SiS Pa LAS uty NE
#
# ----------------------------------------
# Image: 52.png
# OCR Output:
# wet Sib IE lee SLL
#
# ----------------------------------------
# Image: 53.png
# OCR Output:
# BP Se 6 gh 660 i tus oT
#
# ----------------------------------------
# Image: 34.png
# OCR Output:
# SS SAM US SIs E HW
#
# ----------------------------------------
# Image: 32.png
# OCR Output:
#
# ----------------------------------------
